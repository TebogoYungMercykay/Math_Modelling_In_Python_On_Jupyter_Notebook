# %%
def pell_recursive(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return 2*pell_recursive(n-1)+pell_recursive(n-2)

# %%
pell_recursive(20)
# Out:
# 15994428

# %%
pell_recursive(5)
# Out:
# 29

# %%
pell_recursive(0)
# Out:
# 0

# %%
def pell_non_recursive(n):
    pell_seq = [0,1]
    for k in range (2, n+1):
        pell_seq.append(2*pell_seq[k-1]+pell_seq[k-2])
    
    return pell_seq[n]

# %%
pell_non_recursive(0)
# Out:
# 0

# %%
pell_non_recursive(1)
# Out:
# 1

# %%
pell_non_recursive(67)
# Out:
# 15646814150613670132332869

# %%
import numpy as npy

# %%
import matplotlib.pyplot as plt

# %%
f = lambda x : 6*x**4 + 80*x**3 - 300*x**2 + 20

# %%
x = npy.linspace(-9, 6, 100)

# %%
y = f(x)

# %%
fig, ax =plt.figure(), plt.axes()

ax.plot(x,y, "orange")

plt.show()
