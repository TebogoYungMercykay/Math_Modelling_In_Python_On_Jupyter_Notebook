# %%
S=[1,2,3,4,5]

# %%
G=[3,2,4,6,2]

# %%
def sorted(S):
    flag=0
    i=1
    for i in range(1, len(S)):
        if(S[i]<S[i-1]):
            flag=1
        i+=1
    if(not flag):
        return True
    else:
        return False

# %%
sorted(G)
# Out:
# False

# %%
sorted(S)
# Out:
# True
